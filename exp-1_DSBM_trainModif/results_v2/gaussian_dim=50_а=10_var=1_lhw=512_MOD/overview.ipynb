# %%
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
img1 = mpimg.imread('convergence_cov_inTime.png')
axes[0].imshow(img1)
axes[0].axis('off')

img2 = mpimg.imread('convergence_mean_inTime.png')
axes[1].imshow(img2)
axes[1].axis('off')

img3 = mpimg.imread('convergence_var_inTime.png')
axes[2].imshow(img3)
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
img1 = mpimg.imread('iter_2-b.png')
axes[0].imshow(img1)
axes[0].axis('off')

img2 = mpimg.imread('iter_150-b.png')
axes[1].imshow(img2)
axes[1].axis('off')

img3 = mpimg.imread('iter_300-b.png')
axes[2].imshow(img3)
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %%
pd.read_csv('df_wasserstein_distance.csv')
# Out:
#    Unnamed: 0  sample_№  inference_time  2-wasserstein_distance      mean  \
# 0           0         0        0.939060              140.940478 -9.906919
# 1           1         1        0.913098              140.949837 -9.909934
# 2           2         2        0.962062              140.913928 -9.909574
# 3           3         3        0.898467              140.963980 -9.903679
# 4           4         4        0.922854              140.916530 -9.908718
# 5           5         5        0.895926              140.944250 -9.907799
# 6           6         6        0.915218              140.951399 -9.908957
# 7           7         7        0.931369              140.924383 -9.908795
# 8           8         8        0.921417              141.005898 -9.911349
# 9           9         9        0.931482              141.029119 -9.906470
#
#         var       cov
# 0  1.046404  0.621691
# 1  1.050970  0.623079
# 2  1.048121  0.623137
# 3  1.052164  0.627542
# 4  1.048961  0.623232
# 5  1.051116  0.623617
# 6  1.049014  0.623927
# 7  1.047707  0.621773
# 8  1.052503  0.626704
# 9  1.046822  0.622232
